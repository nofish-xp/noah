# %% [markdown]
# # <font color="blue">编程任务8</font>
# 本次编程任务需要安装·matplotlib
#
# 1，        生成一个值在0～1之间的随机数（服从统一分布）
#
# 2，        随机生成10个值在0～1之间的随机数
#
# 3，        生成一个3*4的数组，值为0～1之间的随机数
#
# 4，        随机生成100个数，服从标准正态分布（均值为0，标准差为1），用matplotlib画出分布图
#
# 5，        随机生成3*4的数组，服从标准正态分布（均值为0，标准差为1）
#
# 6，        随机生成100个数，服从标准正态分布（均值为1，标准差为5），用matplotlib画出分布图
#
# 7，        随机生成一个值在0～99之间的整数
#
# 8，        随机生成100个值在0～99之间的整数， 用matplotlib画出分布图
#
# 9，        随机生成值在0～99之间的3*4的整数数组
#
# 10，      在0～49之间生成等差数列，生成元素个数为25

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#1， 生成一个值在0～1之间的随机数（服从统一分布）
a1 = np.random.rand()
print(a1)
# Out:
# 0.5853506909931563

# %%
#2， 随机生成10个值在0～1之间的随机数
a2 = np.random.rand(10)
print(a2)
# Out:
# [ 0.8725183   0.24266047  0.24069509  0.72049743  0.42651965  0.5021924
#   0.8881563   0.74712444  0.67159076  0.62108289]

# %%
#其他实现方式
a2 = np.random.uniform(0, 1, 10)
a2
# Out:
# array([ 0.4411107 ,  0.1488528 ,  0.51702352,  0.51571646,  0.33006968,
#         0.88687887,  0.85660311,  0.95640052,  0.59699074,  0.26335602])

# %%
#3， 生成一个3*4的数组，值为0～1之间的随机数
a3 = np.random.rand(3, 4)
print(a3)
# Out:
# [[ 0.58102927  0.98859912  0.98625835  0.37693988]
#  [ 0.56608281  0.51361212  0.59449203  0.9927796 ]
#  [ 0.51835295  0.64381557  0.57899269  0.42017339]]

# %%
#4， 随机生成100个数，服从标准正态分布（均值为0，标准差为1），用matplotlib画出分布图
a4 = np.random.randn(100)
plt.plot(x, a4, 'o')
plt.show()

# %%
#5， 随机生成3*4的数组，服从标准正态分布（均值为0，标准差为1）
a5 = np.random.randn(3, 4)
print(a5)
# Out:
# [[ 0.32892132 -0.52214991 -1.22621488 -0.06971784]
#  [ 0.77090758  0.18775422 -1.31086356  0.47989612]
#  [ 0.58674516 -1.29039198 -0.64982103  0.42074746]]

# %%
#6， 随机生成100个数，服从标准正态分布（均值为1，标准差为5），用matplotlib画出分布图
a6 = 5 * np.random.randn(100) + 1
plt.plot(a6, 'o')
plt.show()

# %%
#其他实现方式
# %matplotlib inline
a6 = np.random.normal(1, 5, 100)
plt.plot(a6, 'o')

# %%
#7， 随机生成一个值在0～99之间的整数
a7 = np.random.randint(100)
print(a7)
# Out:
# 18

# %%
#8， 随机生成100个值在0～99之间的整数， 用matplotlib画出分布图
a8 = np.random.randint(0, 100 , size=100)
x = np.random.rand(100)
plt.plot(a8, 'o')
plt.show()

# %%
#9， 随机生成值在0～99之间的3*4的整数数组
a9 = np.random.randint(0, 100, (3, 4))
print(a9)
# Out:
# [[78 94 35 86]
#  [70 37  4 19]
#  [23 94 70 95]]

# %%
#10， 在0～49之间生成等差数列，生成元素个数为25 TODO是想要这种效果？
a10 = np.linspace(0, 49, 25)
print(a10)
# Out:
# [  0.           2.04166667   4.08333333   6.125        8.16666667
#   10.20833333  12.25        14.29166667  16.33333333  18.375       20.41666667
#   22.45833333  24.5         26.54166667  28.58333333  30.625       32.66666667
#   34.70833333  36.75        38.79166667  40.83333333  42.875       44.91666667
#   46.95833333  49.        ]
